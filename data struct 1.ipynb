# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(np.arange(1,6)) #when you give only one argument it consider it as y
plt.ylabel('five integers')
# Out:
# Text(0, 0.5, 'five integers')

# %%
plt.plot(np.arange(1,8),np.arange(2,16,2))
plt.xlabel('x_integers')
plt.ylabel('y_integers')
# Out:
# Text(0, 0.5, 'y_integers')

# %%
plt.plot(np.arange(3,18,3),np.arange(2,12,2),'ro') # ro===red circle
plt.plot(np.arange(2,15),np.linspace(1,17,13),"g^")

# %%
plt.plot(np.arange(5,10),np.arange(2,7),'bo')
plt.axis([0,15,0,10])
# Out:
# [0, 15, 0, 10]

# %%
fig_1=plt.figure(1)
plot_1=fig_1.add_subplot(121)
plot_2=fig_1.add_subplot(122)

# %%
raw_fig=plt.figure(1)
plot1=raw_fig.add_subplot(12,1,1)
plot1=raw_fig.add_subplot(12,1,2)

# %%
figu=plt.figure(figsize=(3,8))
plot1=figu.add_subplot(321)

# %%
raw=plt.figure(figsize=(8,5))
plot1=raw.add_subplot(212)
plt.plot(np.arange(1,10),np.arange(4,13),'ro')

# %%
#plt.rcParams['figure.figsize']=(8,6)
#plt.rcParams['lines.linewidth']=2
#plt.rcParams['figure.facecolor']='y'
#plt.rcParams['axes.grid']=True

raw1=plt.figure(figsize=(6,4))
plot1=raw1.add_subplot(212)
plt.plot(np.arange(2,10,2),np.arange(1,5),)
plt.show()

# %%
# import glass dataset
col_names = ['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type']
df = pd.read_table('https://archive.ics.uci.edu/ml/machine-learning-databases/glass/glass.data', \
                   sep = ',', header = None, index_col = 0, names = col_names)
print(df.head())
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
plt.plot(df['RI'],'bo')
plt.xlabel('Index')
plt.ylabel('Refr index')
# Out:
# Text(0, 0.5, 'Refr index')

# %%
plt.plot(df['Na'],df["Mg"],'ro')
plt.xlabel('sodium')
plt.ylabel('magnesium')
# Out:
# Text(0, 0.5, 'magnesium')

# %%
plt.rcParams["figure.figsize"] = (8,4)
plt.plot(df['Mg'],'ro',label='magnesium')
plt.plot(df['Na'],'bo',label="sodium")
plt.legend(loc='lower left')
plt.xlabel('Index',fontsize=20)
plt.title('Na and Mg plot',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Na and Mg plot')

# %%
#Plotting time series data
data=pd.read_table('names.txt',sep=",",index_col=0,header=0)
data.head()
# Out:
#       Year Gender  Count
# Name
# Jane  1880      F    215
# Jane  1881      F    216
# Jane  1882      F    254
# Jane  1883      F    247
# Jane  1884      F    295

# %%
raw_data=data.loc[['Jane', 'Alice', 'Elizabeth', 'Stella', 'Mathilda']]
raw_data.to_csv('name_part.csv')

# %%
raw_data=pd.read_csv('name_part.csv',index_col=0)
print(raw_data.head())
# Out:
#       Year Gender  Count
# Name
# Jane  1880      F    215
# Jane  1881      F    216
# Jane  1882      F    254
# Jane  1883      F    247
# Jane  1884      F    295

# %%
#selecting only jane
data_jane=raw_data.loc[['Jane']]
data_jane.set_index('Gender',inplace=True)
print(data_jane.head())
# Out:
#         Year  Count
# Gender
# F       1880    215
# F       1881    216
# F       1882    254
# F       1883    247
# F       1884    295

# %%
#separating male and female
jane_male=data_jane.loc[['M']]
jane_female=data_jane.loc[['F']]
print(jane_male.head())
print(jane_female.head())
# Out:
#         Year  Count
# Gender
# M       1907      5
# M       1908      5
# M       1910      6
# M       1913      7
# M       1915     15
#         Year  Count
# Gender
# F       1880    215
# F       1881    216
# F       1882    254
# F       1883    247
# F       1884    295

# %%
plt.figure(figsize=(8,4))
plt.plot(jane_male['Year'],jane_male['Count'],'r--',label='Male')
plt.plot(jane_female['Year'],jane_female['Count'],'b-',label='female')
plt.legend()
plt.xlabel('Years')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
X=np.arange(100)
print(len(X))
Y=np.random.randn(100)*10
print(len(Y))
# Out:
# 100
# 100

# %%
plt.plot(X,Y,label="Y",color='g',marker='*')
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()
plt.savefig('random.png')

# %%
# how to create figure and subplots at once
fig,(ax1,ax2)=plt.subplots(nrows=2,ncols=1,facecolor='y',figsize=(6,4),edgecolor='r')

# %%
fig.get_axes()
fig.delaxes(ax1)
fig.get_axes()

# %%
x=np.linspace(0,20,200)
y=np.sin(x)
plt.figure(figsize=(8,4))
plt.plot(x,y,'b--',linewidth = 2,label='sine_functn')
plt.xlabel('freq')
plt.ylabel('sine_value')
plt.title('sine_wave',fontsize=20)
plt.legend(loc='best')
plt.grid()

# %%
raw=plt.figure(1,figsize=(8,4),facecolor=None,edgecolor='b')
plot1=raw.add_subplot(211)
plot1.scatter(np.arange(1,10),np.arange(5,14))

# %%
# fancier scatterplot
x = np.random.rand(100)
y = np.random.rand(100)
c = np.random.rand(100)
a = np.random.rand(100)*100

fig = plt.figure(1, figsize = (10, 6), facecolor = None, edgecolor = 'b')
ax = fig.add_subplot(2, 1, 1)
ax.scatter(x,y,c=c,s=a)
plt.show()

# %%
x=np.random.randn(100)*10
y=np.random.rand(100)
plt.figure(figsize=(8,4) , facecolor='y')
plt.bar(x,y)
# Out:
# <BarContainer object of 100 artists>

# %%
plt.barh(x,y)
# Out:
# <BarContainer object of 100 artists>

# %%
plt.figure(figsize=(8,4),facecolor='wheat',edgecolor='tan')
x=np.arange(0,10)
y=np.arange(10,20)
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
plt.bar(x,y)
plt.xticks(x,labels)
# Out:
# ([<matplotlib.axis.XTick at 0x143c4730>,
# ...
#  <a list of 10 Text xticklabel objects>)

# %%
data=pd.read_csv('2019.csv',names=['rank','country','score','gdp','social support','Health','freedom','generocity',
                                   'corruption'],header=0)
data.count()
# Out:
# rank              156
# country           156
# score             156
# gdp               156
# social support    156
# Health            156
# freedom           156
# generocity        156
# corruption        156
# dtype: int64

# %%
## plotting happiness score vs country
plt.figure(figsize=(8,6))
plt.bar(data['country'][0:10],data['score'][0:10],color='b')
plt.xlabel('country')
plt.ylabel('happines score')
plt.title('countries happpiness score',fontsize=20)
# Out:
# Text(0.5, 1.0, 'countries happpiness score')

# %%
# stacked bar chart
names=['a','b','c','d']
scores = [80, 99, 75, 95]
plt.bar(range(len(names)), scores)
plt.xticks(range(len(names)), names)
# Out:
# ([<matplotlib.axis.XTick at 0x15ec3290>,
# ...
#  <a list of 4 Text xticklabel objects>)

# %% [markdown]
# ## pandas

# %%
s1=pd.Series(10)
print(s1)
print(pd.Series(5,index=range(5)))
print(pd.Series(2,index=['a','b','c','d']))
# Out:
# 0    10
# dtype: int64
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# dtype: int64
# a    2
# b    2
# c    2
# d    2
# dtype: int64

# %%
print(pd.Series([1,2,3,4]))
print(pd.Series(('a','b','c')))
print(pd.Series(np.ones(4)))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# 0    a
# 1    b
# 2    c
# dtype: object
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# dtype: float64

# %%
dictionary = {0: 'a', 1: 'b', 2: 'c'}
s2 = pd.Series(dictionary)
print(s2)
print(s2.index)
print(s2.values)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object
# Int64Index([0, 1, 2], dtype='int64')
# ['a' 'b' 'c']

# %%
data=pd.read_csv('2019.csv',names=['rank','country','score','gdp','social support','Health','freedom','generocity',
                                   'corruption'],header=0)
raw_data=data[0:10]
raw_data
# Out:
#    rank      country  score    gdp  social support  Health  freedom  \
# 0     1      Finland  7.769  1.340           1.587   0.986    0.596
# 1     2      Denmark  7.600  1.383           1.573   0.996    0.592
# 2     3       Norway  7.554  1.488           1.582   1.028    0.603
# 3     4      Iceland  7.494  1.380           1.624   1.026    0.591
# 4     5  Netherlands  7.488  1.396           1.522   0.999    0.557
# 5     6  Switzerland  7.480  1.452           1.526   1.052    0.572
# 6     7       Sweden  7.343  1.387           1.487   1.009    0.574
# 7     8  New Zealand  7.307  1.303           1.557   1.026    0.585
# 8     9       Canada  7.278  1.365           1.505   1.039    0.584
# 9    10      Austria  7.246  1.376           1.475   1.016    0.532
#
#    generocity  corruption
# 0       0.153       0.393
# 1       0.252       0.410
# 2       0.271       0.341
# 3       0.354       0.118
# 4       0.322       0.298
# 5       0.263       0.343
# 6       0.267       0.373
# ...

# %%
plt.scatter(raw_data['rank'],raw_data['gdp'])

# %%
idx = np.random.randint(0, 10, 10)   # create random index
col1 = np.random.randint(0, 10, 10)
col2 = np.random.randint(0, 10, 10)
col3 = np.random.randint(0, 10, 10)

df = pd.DataFrame({'col1': col1, 'col2': col2, 'col3': col3}, index = idx)
data=df.head()
data
# Out:
#    col1  col2  col3
# 6     3     2     2
# 4     9     5     7
# 7     0     3     9
# 2     0     4     6
# 5     3     9     9

# %%
data.sort_index()
# Out:
#    col1  col2  col3
# 2     0     4     6
# 4     9     5     7
# 5     3     9     9
# 6     3     2     2
# 7     0     3     9

# %%
data.sort_index(ascending=False)
# Out:
#    col1  col2  col3
# 7     0     3     9
# 6     3     2     2
# 5     3     9     9
# 4     9     5     7
# 2     0     4     6

# %%
data.sort_values(by=['col1','col2'],ascending=[False,True])
# Out:
#    col1  col2  col3
# 4     9     5     7
# 6     3     2     2
# 5     3     9     9
# 7     0     3     9
# 2     0     4     6

# %%
idx = np.arange(10)
col1 = np.random.randint(-10, 10, 10)
col2 = np.random.randint(-10, 10, 10)
col3 = np.random.randint(-10, 10, 10)

df = pd.DataFrame({'col1': col1, 'col2': col2, 'col3': col3}, index = idx)
data=df.head()
data
# Out:
#    col1  col2  col3
# 0    -8    -4    -7
# 1    -1     3     1
# 2    -2     9    -2
# 3    -8    -4     0
# 4    -2    -2    -5

# %%
data[data>0]
# Out:
#    col1  col2  col3
# 0   NaN   NaN   NaN
# 1   NaN   3.0   1.0
# 2   NaN   9.0   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN

# %%
data[data>-8]
# Out:
#    col1  col2  col3
# 0   NaN    -4    -7
# 1  -1.0     3     1
# 2  -2.0     9    -2
# 3   NaN    -4     0
# 4  -2.0    -2    -5

# %%
data[data.col2>0]
# Out:
#    col1  col2  col3
# 1    -1     3     1
# 2    -2     9    -2

# %%
col_names = ['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type']
glass=pd.read_table('glass.txt',sep=",",names=col_names,header=None)
glass.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
glass.to_csv('glass.csv')
gdata=pd.read_csv('glass.csv',index_col=0)
gdata.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
# data can be grouped using groupby() function
grouped = gdata.groupby('Type')
grouped.head(1)
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  Type
# 1    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00     1
# 71   1.51574  14.86  3.67  1.74  71.87  0.16  7.36  0.00  0.12     2
# 147  1.51769  13.65  3.66  1.11  72.77  0.11  8.60  0.00  0.00     3
# 164  1.51514  14.01  2.68  3.50  69.89  1.68  5.87  2.20  0.00     5
# 177  1.51905  14.00  2.39  1.56  72.37  0.00  9.57  0.00  0.00     6
# 186  1.51131  13.69  3.20  1.81  72.81  1.76  5.43  1.19  0.00     7

# %%
# generating df
idx = np.random.randint(0, 2, 10)   # create random index (0 or 1)
col1 = np.random.randint(0, 5, 10)
col2 = np.random.randint(0, 5, 10)
col3 = np.random.randint(0, 5, 10)

df = pd.DataFrame({'col1': col1, 'col2': col2, 'col3': col3}, index = idx)
df.count()
# Out:
# col1    10
# col2    10
# col3    10
# dtype: int64

# %%
# getting row idx
idx = df.index         # as series
print(idx)
idx = list(idx)     # as list
print(idx)
# Out:
# Int64Index([0, 1, 0, 1, 0, 1, 0, 1, 0, 0], dtype='int64')
# [0, 1, 0, 1, 0, 1, 0, 1, 0, 0]

# %%
# substituting row index by column
df = df.set_index('col1')     # set col1 as index
print(df)
# Out:
#       col2  col3
# col1
# 0        1     1
# 4        1     4
# 2        2     4
# 3        3     3
# 0        0     4
# 3        0     2
# 2        0     0
# 3        0     4
# 1        3     4
# 2        1     0

# %%
df=df.reset_index()

# %%
print(df)
# Out:
#    col1  col2  col3
# 0     0     1     1
# 1     4     1     4
# 2     2     2     4
# 3     3     3     3
# 4     0     0     4
# 5     3     0     2
# 6     2     0     0
# 7     3     0     4
# 8     1     3     4
# 9     2     1     0

# %%
# generating another df
idx = np.random.randint(0, 2, 3)   # create random index (0 or 1)
col1 = np.random.randint(0, 5, 3)
col2 = np.random.randint(0, 5, 3)
col3 = np.random.randint(0, 5, 3)

df_ = pd.DataFrame({'col1': col1, 'col2': col2, 'col3': col3}, index = idx)
df_.head()
# Out:
#    col1  col2  col3
# 0     0     2     4
# 1     2     3     2
# 0     3     4     4

# %%
# note that two dfs should be same column labels
df = df.append(df_)      # adding rows to end of df
df.count()
# Out:
# col1    13
# col2    13
# col3    13
# dtype: int64

# %%
df.drop(0)
# Out:
#    col1  col2  col3
# 1     1     2     2
# 1     3     4     0
# 1     2     3     2

# %%
# generating df
idx = np.random.randint(0, 2, 10)   # create random index (0 or 1)
col1 = np.random.randint(0, 5, 10)
col2 = np.random.randint(0, 5, 10)
col3 = np.random.randint(0, 5, 10)
col4 = np.random.choice(['Python', 'Java', 'C'], size = 10)

df = pd.DataFrame({'col1': col1, 'col2': col2, 'col3': col3, 'col4': col4}, index = idx)
df.head()
# Out:
#    col1  col2  col3    col4
# 1     1     2     2    Java
# 0     4     4     3       C
# 0     2     2     3  Python
# 0     0     1     0  Python
# 1     1     2     2       C

# %%
# using isin() to select rows
df[df['col3'].isin([0, 1])]
# Out:
#    col1  col2  col3    col4
# 0     0     1     0  Python
# 0     0     4     0       C
# 0     3     0     0    Java

# %%
# using isin() to select rows
df[df['col4'].isin(['Python'])]
# Out:
#    col1  col2  col3    col4
# 0     2     2     3  Python
# 0     0     1     0  Python
# 0     0     2     3  Python

# %%
df[df['col4'].str.contains('Pyth')]
# Out:
#    col1  col2  col3    col4
# 0     2     2     3  Python
# 0     0     1     0  Python
# 0     0     2     3  Python

# %%
# dropping duplicates
df.drop_duplicates(subset = 'col4')
# Out:
#    col1  col2  col3    col4
# 1     1     2     2    Java
# 0     4     4     3       C
# 0     2     2     3  Python

# %%
df=pd.read_table('names.txt',index_col=0,sep=",",header=0)
df.head()
# Out:
#       Year Gender  Count
# Name
# Jane  1880      F    215
# Jane  1881      F    216
# Jane  1882      F    254
# Jane  1883      F    247
# Jane  1884      F    295

# %%
bool_vec_1 = df.index == 'Jane'
bool_vec_2 = np.array(df['Year'] >= 2000)
bool_vec_3 = np.array(df['Gender'] == 'F')
print(len(bool_vec_1))
print(len(bool_vec_2))
print(len(bool_vec_3))

bool_vector = bool_vec_1 & bool_vec_2 & bool_vec_3
print(len(bool_vector))
# Out:
# 1029
# 1029
# 1029
# 1029

# %%
# select only rows that satisfy condition
df_partial = df[bool_vector]
print(df_partial)
# Out:
#       Year Gender  Count
# Name
# Jane  2000      F    647
# Jane  2001      F    670
# Jane  2002      F    696
# Jane  2003      F    704
# Jane  2004      F    657
# Jane  2005      F    650
# Jane  2006      F    664
# Jane  2007      F    774
# Jane  2008      F    826
# Jane  2009      F    831
# Jane  2010      F    833
# Jane  2011      F    867
# Jane  2012      F    927
# Jane  2013      F    898
# Jane  2014      F   1018

# %%
# plotting occurrences of femal name 'Jane'
df_partial.plot(x = 'Year', y = 'Count')
plt.show()
